# %% [markdown]
# ### Video 21 Preparing the dataset

# %%
import pandas as pd
import bar_chart_race as bcr
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("time_series_covid19_confirmed_global.csv")
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/31/20  8/1/20  8/2/20  8/3/20  \
# 0        0        0        0        0  ...    36675   36710   36710   36747
# 1        0        0        0        0  ...     5276    5396    5519    5620
# 2        0        0        0        0  ...    30394   30950   31465   31972
# 3        0        0        0        0  ...      925     925     925     937
# 4        0        0        0        0  ...     1148    1164    1199    1280
#
#    8/4/20  8/5/20  8/6/20  8/7/20  8/8/20  8/9/20
# ...

# %%
df.drop(["Lat", "Long"], axis = "columns", inplace=True)
df.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  7/31/20  8/1/20  8/2/20  8/3/20  8/4/20  \
# 0        0        0        0  ...    36675   36710   36710   36747   36782
# 1        0        0        0  ...     5276    5396    5519    5620    5750
# 2        0        0        0  ...    30394   30950   31465   31972   32504
# 3        0        0        0  ...      925     925     925     937     939
# 4        0        0        0  ...     1148    1164    1199    1280    1344
#
#    8/5/20  8/6/20  8/7/20  8/8/20  8/9/20
# ...

# %%
# Remove repeted Country/Region by summing up it

df = df.groupby("Country/Region").sum()
df.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  7/31/20  8/1/20  \
# ...

# %%
# Changing the rows to columns

df = df.T
df.head()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          4        0
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
# Set the index as a datetime index
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#                '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#                '2020-01-30', '2020-01-31',
#                ...
#                '2020-07-31', '2020-08-01', '2020-08-02', '2020-08-03',
#                '2020-08-04', '2020-08-05', '2020-08-06', '2020-08-07',
#                '2020-08-08', '2020-08-09'],
#               dtype='datetime64[ns]', length=201, freq=None)

# %%
# Create the barchart
bcr.bar_chart_race(
    df = df, 
    filename = "covid19_final.mp4",
    orientation = 'h',
    sort = 'desc',
    n_bars = 10,
    fixed_order = False,
    fixed_max = False,
    steps_per_period = 10,
    period_length = 250,
    interpolate_period = False,
    label_bars = True,
    bar_size = 0.95,
    period_label = True, 
    period_fmt = "%B %d, %Y",
    period_summary_func = lambda v, r: {'x': .99, 'y': .3,
                                      's': f'Total cases: {v.nlargest(6).sum():,.0f}',
                                      'ha': 'right', 'size': 9, 'family': 'Courier New'},
    perpendicular_bar_func = None,
    figsize = (6, 3.5),
    cmap = None,
    title = "Top 10 countries - Covid19 Cases",
    title_size = None,
    bar_label_size = 7,
    tick_label_size = 7,
    shared_fontdict = None,
    scale = 'linear',
    writer = None,
    fig = None,
    dpi = 300,
    bar_kwargs = None,
    filter_column_colors = False
)
